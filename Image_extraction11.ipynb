# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"E:\Project\Data for Image Extraction\CompletedPM_1_6_2023.xlsx",sheet_name='EB CheckList')

# %%
df
# Out:
#       SiteId                           SiteName          Circle  \
# 0     013213      KURHPSC0253(Anusaya Building)     Maharashtra
# 1     012798                APHB COLONY SURARAM  Andhra Pradesh
# 2     010767  BEGUM MOHALLA ,Gummanahallly sira       Karnataka
# 3     011930                          Shishgarh         UP West
# 4     012843                             Huligi       Karnataka
# ...      ...                                ...             ...
# 8687  010588             Pichampalayam Tiruppur      Tamil Nadu
# 8688  010736                New Pankajam Colony      Tamil Nadu
# 8689  010661              Venkatesh nagar Hosur      Tamil Nadu
# 8690  009927                 Sara Soule Pvt Ltd      Tamil Nadu
# 8691  013297                        Bari Basahi         UP East
#
#                PM_ID       FEID VerifyStatus                     Reason  \
# 0     PMDEC221287355   OM-T2269     Approved                        NaN
# ...

# %%
df.EB_SelfieImage
# Out:
# 0       https://telecomimages.s3.ap-south-1.amazonaws....
# 1       https://telecomimages.s3.ap-south-1.amazonaws....
# 2       https://telecomimages.s3.ap-south-1.amazonaws....
# 3       https://telecomimages.s3.ap-south-1.amazonaws....
# 4       https://telecomimages.s3.ap-south-1.amazonaws....
#                               ...
# 8687    https://telecomimages.s3.ap-south-1.amazonaws....
# 8688    https://telecomimages.s3.ap-south-1.amazonaws....
# 8689    https://telecomimages.s3.ap-south-1.amazonaws....
# 8690    https://telecomimages.s3.ap-south-1.amazonaws....
# 8691    https://telecomimages.s3.ap-south-1.amazonaws....
# Name: EB_SelfieImage, Length: 8692, dtype: object

# %%
import urllib.request
from PIL import Image

# %%
urllib.request.urlretrieve("https://telecomimages.s3.ap-south-1.amazonaws.com/NewPM/2022/122022/34435/PMDEC221287355_EB_SelfieImage_1_1670394219437.png","pics/name.png")
# img = Image.open("gfg.png")
# img.show()
# Out:
# ('pics/name.png', <http.client.HTTPMessage at 0x209219da580>)

# %%
df=df[df['EB_SelfieImage'].notna()]

# %%
import time
s= time.time()
c=0
for i in df.EB_SelfieImage:
    c=c+1
    urllib.request.urlretrieve(i,f"pics/Fig_{c}.png")
e= time.time()

# %%
e-s
# Out:
# 3812.0802648067474

# %%
df.EB_SelfieImage.isnull().sum()
# Out:
# 0

# %%
df
# Out:
#       SiteId                           SiteName          Circle  \
# 0     013213      KURHPSC0253(Anusaya Building)     Maharashtra
# 1     012798                APHB COLONY SURARAM  Andhra Pradesh
# 2     010767  BEGUM MOHALLA ,Gummanahallly sira       Karnataka
# 3     011930                          Shishgarh         UP West
# 4     012843                             Huligi       Karnataka
# ...      ...                                ...             ...
# 8687  010588             Pichampalayam Tiruppur      Tamil Nadu
# 8688  010736                New Pankajam Colony      Tamil Nadu
# 8689  010661              Venkatesh nagar Hosur      Tamil Nadu
# 8690  009927                 Sara Soule Pvt Ltd      Tamil Nadu
# 8691  013297                        Bari Basahi         UP East
#
#                PM_ID       FEID VerifyStatus                     Reason  \
# 0     PMDEC221287355   OM-T2269     Approved                        NaN
# ...
